# %%
import pandas as pd
from sklearn.cluster import KMeans

# %% [markdown]
# # Объединение по средним значениям за каждый день

# %%
df1 = pd.read_csv('../data/processed/cleaned_air_data_with_aqi_and_coordinates.csv')
df2 = pd.read_csv('../data/processed/cleaned_weather_data.csv')

# %%
df1.date = pd.to_datetime(df1.date).dt.date

# %%
df2['date'] = pd.to_datetime(df2.time).dt.date

# %%
date = df2['date']
df2.drop(labels=['date'], axis=1,inplace = True)
df2.insert(0, 'date', date)

# %%
df1 = df1.drop(['station_name', 'latitude', 'longitude'], axis=1)

# %%
df2 = df2.drop('time', axis=1)

# %%
df1_mean = df1.groupby('date').mean()

# %%
df2_mean = df2.groupby('date').mean()

# %%
merged = pd.merge(df1_mean, df2_mean, on='date').reset_index()

# %%
df1_statistics = pd.merge(pd.merge(df1.groupby('date').min().reset_index(), df1.groupby('date').max().reset_index(), on='date', suffixes=['_min', '_max']), df1.groupby('date').mean().reset_index(), on='date')
columns = df1_statistics.columns.tolist()
columns[-6:] = [x + '_mean' for x in columns[-6:]]
df1_statistics.columns = columns

# %%
df2_statistics = pd.merge(pd.merge(df2.groupby('date').min().reset_index(), df2.groupby('date').max().reset_index(), on='date', suffixes=['_min', '_max']), df2.groupby('date').mean().reset_index(), on='date')
columns = df2_statistics.columns.tolist()
columns[-9:] = [x + '_mean' for x in columns[-9:]]
df2_statistics.columns = columns

# %%
merged_full_statistics = pd.merge(df1_statistics, df2_statistics, on='date').reset_index()

# %%
merged.to_csv('../data/extracted/merged_by_date.csv', index=False)

# %%
merged_full_statistics.to_csv('../data/extracted/merged_by_date_full.csv', index=False)

# %% [markdown]
# # Класстеризация по расстоянию до центра

# %%
df1 = pd.read_csv('../data/processed/cleaned_air_data_with_aqi_and_coordinates.csv')
df2 = pd.read_csv('../data/processed/cleaned_weather_data.csv')

# %%
moscow_center = [55.7522, 37.6156]

# %%
df1['distance_to_center'] = (abs(df1.iloc[:, -2:] - moscow_center)).sum(axis=1)

# %%
df1.distance_to_center.min(), df1.distance_to_center.max()
# Out:
# (0.02716999999999814, 0.6907520000000034)

# %%
df1
# Out:
#             date  pm25  pm10        o3    no2   co  \
# 0     2024-12-04  23.0  12.0  0.008000  0.014  1.0
# 1     2024-12-04  13.0  12.0  0.013267  0.017  2.0
# 2     2024-12-04  26.0  22.0  0.006000  0.019  4.0
# 3     2024-12-04  12.0  11.0  0.017667  0.021  2.0
# 4     2024-12-04   7.0  46.0  0.019411  0.025  3.0
# ...          ...   ...   ...       ...    ...  ...
# 1786  2024-06-06  39.0  16.0  0.014315  0.017  1.0
# 1787  2024-06-06  54.0  29.0  0.026000  0.012  1.0
# 1788  2024-06-06  46.0  23.0  0.013267  0.020  2.0
# 1789  2024-06-06  31.0  11.0  0.020000  0.016  1.0
# 1790  2024-06-06  44.0  22.0  0.024000  0.039  3.0
#
#                               station_name     aqi   latitude  longitude  \
# 0              Mgu, Moscow, Moscow, Russia   73.92  55.707241  37.522410
# 1       Novokosino, Moscow, Moscow, Russia   52.89  55.734445  37.857779
# 2         Zelen_15, Moscow, Moscow, Russia   80.23  55.976936  37.149584
# 3         Narod_op, Moscow, Moscow, Russia   50.00  55.776064  37.475878
# 4            Suhar, Moscow, Moscow, Russia   42.59  55.773757  37.627445
# ...                                    ...     ...        ...        ...
# 1786     Veshnyaki, Moscow, Moscow, Russia  109.62  55.719959  37.795549
# 1787    bazovskaya, Moscow, Moscow, Russia  146.55  55.877509  37.508548
# 1788    Novokosino, Moscow, Moscow, Russia  126.85  55.734445  37.857779
# 1789        Shabol, Moscow, Moscow, Russia   90.75  55.715698  37.605238
# 1790  Ochakovskaya, Moscow, Moscow, Russia  121.93  55.693546  37.455579
#
#       distance_to_center
# 0               0.138149
# 1               0.259934
# 2               0.690752
# 3               0.163586
# 4               0.033402
# ...                  ...
# 1786            0.212190
# 1787            0.232361
# 1788            0.259934
# 1789            0.046864
# 1790            0.218675
#
# [1791 rows x 11 columns]

# %%
model = KMeans(n_clusters=12)

# %%
model.fit(df1.iloc[:, -3:].values)
# Out:
# KMeans(n_clusters=12)

# %%
clusters = model.predict(df1.iloc[:, -3:].values)

# %%
df1['cluster'] = clusters

# %%
df1.to_csv('../data/extracted/df1_with_clusters.csv', index=False)

# %%
merged['test'] = merged.pm25/merged.pm10

# %%
merged.iloc[:, 1:].corr().style.background_gradient(cmap='coolwarm')
# Out:
# /home/nekita473/anaconda3/envs/vision/lib/python3.10/site-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /home/nekita473/anaconda3/envs/vision/lib/python3.10/site-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_7cbe5_row0_col0, #T_7cbe5_row1_col1, #T_7cbe5_row2_col2, #T_7cbe5_row3_col3, #T_7cbe5_row4_col4, #T_7cbe5_row5_col5, #T_7cbe5_row6_col6, #T_7cbe5_row7_col7, #T_7cbe5_row8_col8, #T_7cbe5_row11_col11, #T_7cbe5_row12_col12, #T_7cbe5_row13_col13, #T_7cbe5_row14_col14, #T_7cbe5_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7cbe5_row0_col1, #T_7cbe5_row1_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_7cbe5_row0_col2, #T_7cbe5_row4_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_7cbe5_row0_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_7cbe5_row0_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_7cbe5_row0_col5, #T_7cbe5_row5_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_7cbe5_row0_col6, #T_7cbe5_row13_col3, #T_7cbe5_row15_col14 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_7cbe5_row0_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_7cbe5_row0_col8, #T_7cbe5_row11_col13 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7cbe5_row0_col9, #T_7cbe5_row0_col10, #T_7cbe5_row1_col9, #T_7cbe5_row1_col10, #T_7cbe5_row2_col9, #T_7cbe5_row2_col10, #T_7cbe5_row3_col9, #T_7cbe5_row3_col10, #T_7cbe5_row4_col9, #T_7cbe5_row4_col10, #T_7cbe5_row5_col9, #T_7cbe5_row5_col10, #T_7cbe5_row6_col9, #T_7cbe5_row6_col10, #T_7cbe5_row7_col9, #T_7cbe5_row7_col10, #T_7cbe5_row8_col9, #T_7cbe5_row8_col10, #T_7cbe5_row9_col0, #T_7cbe5_row9_col1, #T_7cbe5_row9_col2, #T_7cbe5_row9_col3, #T_7cbe5_row9_col4, #T_7cbe5_row9_col5, #T_7cbe5_row9_col6, #T_7cbe5_row9_col7, #T_7cbe5_row9_col8, #T_7cbe5_row9_col9, #T_7cbe5_row9_col10, #T_7cbe5_row9_col11, #T_7cbe5_row9_col12, #T_7cbe5_row9_col13, #T_7cbe5_row9_col14, #T_7cbe5_row9_col15, #T_7cbe5_row10_col0, #T_7cbe5_row10_col1, #T_7cbe5_row10_col2, #T_7cbe5_row10_col3, #T_7cbe5_row10_col4, #T_7cbe5_row10_col5, #T_7cbe5_row10_col6, #T_7cbe5_row10_col7, #T_7cbe5_row10_col8, #T_7cbe5_row10_col9, #T_7cbe5_row10_col10, #T_7cbe5_row10_col11, #T_7cbe5_row10_col12, #T_7cbe5_row10_col13, #T_7cbe5_row10_col14, #T_7cbe5_row10_col15, #T_7cbe5_row11_col9, #T_7cbe5_row11_col10, #T_7cbe5_row12_col9, #T_7cbe5_row12_col10, #T_7cbe5_row13_col9, #T_7cbe5_row13_col10, #T_7cbe5_row14_col9, #T_7cbe5_row14_col10, #T_7cbe5_row15_col9, #T_7cbe5_row15_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T